# %%
# Imports
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F


import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset
import matplotlib_inline.backend_inline as backend_inline
from torchsummary import summary
import copy

backend_inline.set_matplotlib_formats("svg")


#### Pytorch device specific configuration ###

# # Pytorch Gpu Configuration for Cuda
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Pytorch Gpu Configuration for directml(AMD GPU)
# import torch_directml

# device = torch_directml.device()

# Set default device
torch.set_default_device(device)

# %%
# Create Gaussian blurs with varying widths and occluding bars
nGauss = 4000
imgSize = 91

x = np.linspace(-4, 4, imgSize)
X, Y = np.meshgrid(x, x)

# Vary the width smoothly
widths = np.linspace(2, 20, nGauss)

# Initialize tensor containing Gaussian blur images
images = torch.zeros(nGauss, 1, imgSize, imgSize)
images_occ = torch.zeros(nGauss, 1, imgSize, imgSize)

for i in range(nGauss):
    # Create Gaussian blur
    ro = 1.5 * np.random.randn(2)  # ro => Random offset
    G = np.exp(-((X - ro[0]) ** 2 + (Y - ro[1]) ** 2) / (widths[i]))

    # And add some noise
    G = G + np.random.randn(imgSize, imgSize) / 5
    images[i, :, :, :] = torch.tensor(G).view(1, imgSize, imgSize)

    # Add random bar randomly
    i1 = np.random.choice(np.arange(2, 28))
    i2 = np.random.choice(np.arange(2, 6))

    if np.random.randn() > 0:
        G[i1 : i1 + i2,] = 1
    else:
        G[:, i1 : i1 + i2] = 1

    # Add to the tensor images
    images_occ[i, :, :, :] = torch.tensor(G).view(1, imgSize, imgSize)

# images = torch.cat((images, images_occ), 0)

# %%
# Create the CNN Autoencoder model
def create_model():
    class CNN_AE_Gauss(nn.Module):
        def __init__(self):
            super().__init__()

            # Encoder
            self.enc = nn.Sequential(
                nn.Conv2d(1, 6, 3, padding=1),
                nn.ReLU(),
                nn.AvgPool2d(2, 2),
                nn.Conv2d(6, 4, 3, padding=1),
                nn.ReLU(),
                nn.AvgPool2d(2, 2),
            )

            # Decoder
            self.dec = nn.Sequential(
                nn.ConvTranspose2d(4, 6, 3, 2),
                nn.ReLU(),
                nn.ConvTranspose2d(6, 1, 3, 2),
            )

        def forward(self, x):
            x = self.enc(x)
            x = self.dec(x)
            # x = torch.tanh(x)  # Ensure output is in the range [0, 1]
            return x

    # Model instance
    net = CNN_AE_Gauss().to(device)

    # Optimizer
    optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

    return net, optimizer

# %%
# Create the function to train the model
def function_train_the_model(
    nGauss, images_input, images_target, epochs, batch_size, lossFun
):
    # Create the Model
    net, optimizer = create_model()

    # Initialize losses
    losses = torch.zeros(epochs)

    # Loop over epochs
    for epoch in range(epochs):

        # Pick random set of images
        pics_for_training = np.random.choice(nGauss, size=batch_size, replace=False)
        X = images_input[pics_for_training, :, :, :]
        Y = images_target[pics_for_training, :, :, :]

        # Forward pass and loss
        yHat = net(X)
        loss = lossFun(yHat, Y)
        losses[epoch] = loss.cpu().item()

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # End of epochs
    print("Training complete")
    return net, losses

# %%
myL1Loss = nn.MSELoss()
myL2AvgLoss = nn.MSELoss()
myCorrLoss = nn.MSELoss()

# %%
class myL1Loss_class(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, yHat, y):
        print(f"Loss : {torch.sum(torch.abs(yHat - y)) / y.shape[0]}")
        return torch.sum(torch.abs(yHat - y)) / y.shape[0]


# Instances
myL1Loss = myL1Loss_class()

# %%
# Model Training
lossFunctions = [myL1Loss, myL2AvgLoss, myCorrLoss]
lossFunctions = [myL1Loss]
lossesByFun = []
models = []
for i in range(len(lossFunctions)):
    net, losses = function_train_the_model(
        nGauss, images_occ, images, epochs=7000, batch_size=32, lossFun=lossFunctions[i]
    )
    lossesByFun.append(losses)
    models.append(net)
    print(f'Traing completed for loss function: {i + 1}: Final loss:  {losses[-1]} ')
# Out:
# Loss : 3292.0849609375
# Loss : 3389.564208984375
# Loss : 3151.765625
# Loss : 3426.24658203125
# Loss : 3065.1923828125
# Loss : 2875.9189453125
# Loss : 3354.98486328125
# Loss : 3354.24658203125
# Loss : 3015.749755859375
# Loss : 2982.88232421875
# Loss : 2951.2548828125
# Loss : 3201.301025390625
# Loss : 3130.43798828125
# Loss : 3288.534912109375
# Loss : 3093.9775390625
# Loss : 2800.407958984375
# Loss : 2896.69384765625
# Loss : 3399.59716796875
# Loss : 2880.94140625
# Loss : 2972.762451171875
# Loss : 3048.5009765625
# Loss : 2975.8193359375
# Loss : 3167.69384765625
# Loss : 3037.38818359375
# Loss : 3276.19873046875
# Loss : 2870.26171875
# Loss : 3022.70751953125
# Loss : 2971.7529296875
# Loss : 2939.00146484375
# Loss : 2741.629150390625
# Loss : 3159.9267578125
# Loss : 2957.939697265625
# Loss : 2906.88330078125
# Loss : 3010.08740234375
# Loss : 3267.20556640625
# Loss : 2874.857666015625
# Loss : 2874.62158203125
# Loss : 2927.1240234375
# ...

# %%
plt.plot(
    lossesByFun[0].cpu(), "s-", label=f"myL1Loss: {round(lossesByFun[0][-1].cpu().item(), 5)}"
)
# plt.plot(
#     lossesByFun[1].cpu(),
#     "s-",
#     label=f"myL2AvgLoss: {round(lossesByFun[1][-1].cpu().item(), 5)}",
# )
# plt.plot(
#     lossesByFun[2].cpu(),
#     "s-",
#     label=f"myCorrLoss: {round(lossesByFun[2][-1].cpu().item(), 5)}",
# )
plt.xlabel("Epochs")
plt.ylabel("ALL Custom Loss Functions losses")
plt.title("Model losses")
plt.legend()
plt.show()

# %%
def plot_results(net, loss, X):
    # Visualize some images_occ and compare with the output of the model
    yHat = net(X)

    fig, axs = plt.subplots(2, 10, figsize=(20, 4))

    for i in range(10):
        G = torch.squeeze(X[i, 0, :, :]).cpu().detach()
        O = torch.squeeze(yHat[i, 0, :, :]).cpu().detach()
        axs[0, i].imshow(G, vmin=-1, vmax=1, cmap="jet")
        axs[0, i].set_title(f"Loss: {loss}")

        axs[1, i].imshow(O, vmin=-1, vmax=1, cmap="jet")
        axs[1, i].set_title("Output Image")
    plt.tight_layout()
    plt.show()

# %%
pics_for_training = np.random.choice(nGauss, size=32, replace=False)
X = images_occ[pics_for_training, :, :, :]
for model_i in range(len(models)):
    loss = round(lossesByFun[model_i][-1].cpu().item(), 5)
    model = models[model_i]
    plot_results(net=model, loss=loss, X=X)
